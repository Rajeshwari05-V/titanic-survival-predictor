# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeshwari05-V/titanic-survival-predictor/blob/main/Titanic_Exploration_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-148ee570-bcec-4d88-8f2a-0038a600bbf6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-148ee570-bcec-4d88-8f2a-0038a600bbf6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# If you uploaded a file named 'titanic.csv', use:
import pandas as pd
import io

# Option 1: read the uploaded file (if you used files.upload())
# uploaded is the dict returned by files.upload(); adjust filename if different
# df = pd.read_csv(io.BytesIO(uploaded['titanic.csv']))

# Option 2: if you used seaborn dataset (no upload)
import seaborn as sns
df = sns.load_dataset('titanic')

# Basic exploration
print("=== HEAD ===")
display(df.head())        # shows first 5 rows (works in Colab)
print("\n=== INFO ===")
print(df.info())          # data types and non-null counts
print("\n=== DESCRIBE ===")
display(df.describe(include='all'))  # numeric summary; include='all' shows categorical too

# Extra quick checks
print("\nShape:", df.shape)             # (rows, columns)
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# === HEAD ===
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# === INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
import matplotlib.pyplot as plt
df['survived'].value_counts().plot(kind='bar')
plt.title('Survived (0 = No, 1 = Yes)')
plt.show()

# %%
df.columns         # list of column names
df.dtypes          # data types per column
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 492         0       1    male  55.0      0      0  30.5000        S   First
# 757         0       2    male  18.0      0      0  11.5000        S  Second
# 622         1       3    male  20.0      1      1  15.7417        C   Third
# 218         1       1  female  32.0      0      0  76.2917        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 4      man        True  NaN  Southampton    no   True
# 492    man        True    C  Southampton    no   True
# 757    man        True  NaN  Southampton    no   True
# 622    man        True  NaN    Cherbourg   yes  False
# 218  woman       False    D    Cherbourg   yes   True

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['embarked'].unique()
df['embarked'].nunique()
# Out:
# 3

# %%
# drop rows where 'survived' is missing (not recommended for large loss)
df.dropna(subset=['survived'], inplace=True)

# fill missing age with median
df['age'] = df['age'].fillna(df['age'].median())

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)
df["Embarked"].fillna(df["Embarked"].mode()[0], inplace=True)
df.drop(columns=["Cabin"], inplace=True)
